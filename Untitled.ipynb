# %%
# !pip install librosa matplotlib numpy pydub
# Out:
# Collecting librosa
#   Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.7/260.7 KB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
# Collecting numpy
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in ./zxkj/lib/python3.10/site-packages (from librosa) (4.15.0)
# Collecting scipy>=1.6.0
#   Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
# Requirement already satisfied: decorator>=4.3.0 in ./zxkj/lib/python3.10/site-packages (from librosa) (5.2.1)
# Collecting soxr>=0.3.2
#   Downloading soxr-1.0.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.3/242.3 KB 3.9 MB/s eta 0:00:00a 0:00:01
# Collecting lazy_loader>=0.1
#   Downloading lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# Collecting msgpack>=1.0
#   Downloading msgpack-1.1.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (406 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 406.1/406.1 KB 1.7 MB/s eta 0:00:00a 0:00:01
# Collecting numba>=0.51.0
#   Downloading numba-0.64.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 1.8 MB/s eta 0:00:0000:0100:01
# Collecting soundfile>=0.12.1
#   Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 1.9 MB/s eta 0:00:0000:0100:010m
# Collecting scikit-learn>=1.1.0
#   Using cached scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
# Collecting joblib>=1.0
#   Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.1.0-py3-none-any.whl (23 kB)
# Collecting pooch>=1.1
#   Downloading pooch-1.9.0-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 KB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in ./zxkj/lib/python3.10/site-packages (from matplotlib) (26.0)
# Collecting pyparsing>=3
#   Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pillow>=8
#   Using cached pillow-12.1.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.62.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 1.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.7 in ./zxkj/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.5.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 1.8 MB/s eta 0:00:00a 0:00:01
# Collecting llvmlite<0.47,>=0.46.0dev0
#   Downloading llvmlite-0.46.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 1.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests>=2.19.0 in ./zxkj/lib/python3.10/site-packages (from pooch>=1.1->librosa) (2.32.5)
# Requirement already satisfied: platformdirs>=2.5.0 in ./zxkj/lib/python3.10/site-packages (from pooch>=1.1->librosa) (4.9.4)
# Requirement already satisfied: six>=1.5 in ./zxkj/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: cffi>=1.0 in ./zxkj/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in ./zxkj/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./zxkj/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2026.2.25)
# Requirement already satisfied: idna<4,>=2.5 in ./zxkj/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./zxkj/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./zxkj/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.6.3)
# Installing collected packages: pydub, threadpoolctl, pyparsing, pillow, numpy, msgpack, llvmlite, lazy_loader, kiwisolver, joblib, fonttools, cycler, audioread, soxr, soundfile, scipy, pooch, numba, contourpy, scikit-learn, matplotlib, librosa
# Successfully installed audioread-3.1.0 contourpy-1.3.2 cycler-0.12.1 fonttools-4.62.0 joblib-1.5.3 kiwisolver-1.5.0 lazy_loader-0.5 librosa-0.11.0 llvmlite-0.46.0 matplotlib-3.10.8 msgpack-1.1.2 numba-0.64.0 numpy-2.2.6 pillow-12.1.1 pooch-1.9.0 pydub-0.25.1 pyparsing-3.3.2 scikit-learn-1.7.2 scipy-1.15.3 soundfile-0.13.1 soxr-1.0.0 threadpoolctl-3.6.0

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
from pydub import AudioSegment

# %%
audio_dir = "data/raw_data"

# %%
audio_files = [f for f in os.listdir(audio_dir) if f.endswith(".mp3")]
print("Audio files found: \n")
for f in audio_files:
    print(f)
# Out:
# Audio files found:
#
# 038010_EIT-2A.mp3
# 038015_EIT-1A.mp3
# 038012_EIT-2A.mp3
# 038011_EIT-1A.mp3

# %%
a_data = {}

for audio in audio_files:
    path = os.path.join(audio_dir, audio)
    y, sr = librosa.load(path, sr = 16000)
    a_data[audio] = (y, sr)
    print(audio, "loaded | length:", round(len(y)/sr , 2), "seconds")
# Out:
# 038010_EIT-2A.mp3 loaded | length: 549.63 seconds
# 038015_EIT-1A.mp3 loaded | length: 529.37 seconds
# 038012_EIT-2A.mp3 loaded | length: 1125.55 seconds
# 038011_EIT-1A.mp3 loaded | length: 547.03 seconds

# %%
file  = audio_files[0]
y, sr = a_data[file]

plt.figure(figsize=(14, 5))
librosa.display.waveshow(y, sr=sr)
plt.title(f"Waveform: {file}")
plt.xlabel("Time")
plt.ylabel("amp")

plt.show()

# %%
trim_times = {
    "038010_EIT-2A.mp3":160,
    "038015_EIT-1A.mp3":150,
    "038012_EIT-2A.mp3":739,
    "038011_EIT-1A.mp3":147
}

# %%
after_trim = {}

for file, (y, sr) in a_data.items():
    start = trim_times[file]
    trimd = y[start*sr:]
    after_trim[file] = (trimd, sr)
    print(file, "trimmed | new length: ", round(len(trimd)/sr, 2))
# Out:
# 038010_EIT-2A.mp3 trimmed | new length:  389.63
# 038015_EIT-1A.mp3 trimmed | new length:  379.37
# 038012_EIT-2A.mp3 trimmed | new length:  386.55
# 038011_EIT-1A.mp3 trimmed | new length:  400.03
